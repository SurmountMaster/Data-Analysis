# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\chido\Videos\freecodecamp-data-analysis-with-python-main\freecodecamp-data-analysis-with-python-main\demographic-data-analyzer\adult.data.csv')

df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
round(df[df['sex']=="Male"]['age'].mean(),1)
# Out:
# 39.4

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
len(df['education'])
# Out:
# 32561

# %%
df['education']=="Bachelors"
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32561, dtype: bool

# %%
round(len(df[df['education']=="Bachelors"])/len(df['education'])*100, 1)
# Out:
# 16.4

# %%
higher_education = df['education'].isin( ['Bachelors', 'Masters', 'Doctorate'])
print(higher_education)

lower_education = ~higher_education
print(lower_education)
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32561, dtype: bool
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 32556     True
# 32557     True
# 32558     True
# 32559     True
# 32560     True
# Name: education, Length: 32561, dtype: bool

# %%
higher_education_rich =  ((higher_education) & (df['salary'] == '>50K')).sum() / higher_education.sum() 
print(higher_education_rich)

lower_education_rich =  ((lower_education) &  (df['salary'] == '>50K')).sum() / lower_education.sum()
print(lower_education_rich)
# Out:
# 0.46535843011613937
# 0.173713601914639

# %%
df_desc = df.sort_values(by='hours-per-week', ascending=False).reset_index(drop=True)
df_desc
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       30           Private  103596     HS-grad              9
# 1       37           Private  241174   Bachelors             13
# 2       37           Private  176900     HS-grad              9
# 3       36  Self-emp-not-inc  257250   Assoc-voc             11
# 4       19           Private  121074     7th-8th              4
# ...    ...               ...     ...         ...            ...
# 32556   21           Private  184135     HS-grad              9
# 32557   75                 ?  260543        10th              6
# 32558   69                 ?  117525  Assoc-acdm             12
# 32559   78                 ?  363134     HS-grad              9
# 32560   81                 ?  120478   Assoc-voc             11
#
#            marital-status         occupation    relationship  \
# 0           Never-married    Protective-serv   Not-in-family
# 1      Married-civ-spouse     Prof-specialty         Husband
# ...
